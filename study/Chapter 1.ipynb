# %% [markdown]
# # Hello World, and Welcome to Data 100

# %%
import sys
print(sys.version)
# Out:
# 3.6.12 |Anaconda, Inc.| (default, Sep  8 2020, 17:50:39)
# [GCC Clang 10.0.0 ]

# %%
print("Hello World!")
# Out:
# Hello World!
