# %% [markdown]
# # Hello World, and Welcome to Data 100

# %%
import sys

print(sys.version)
# Out:
# 3.6.4 |Anaconda, Inc.| (default, Jan 16 2018, 12:04:33)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Throughout the course, I'll try to make notes and comprehensive coding guides, to integrate data science, math, and coding all together!
#
# For now, there is nothing much content wise in Lecture 1, other than logistics. Let's have fun!
