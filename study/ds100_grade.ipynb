# %%
hw0 = 23.0 / 23.0
hw1 = (26.0 + 7.0) / (27.0 + 7.0)
hw2 = (24.0 + 8.0) / (24.0 + 11.0)
hw3 = (45.8 + 13.0) / (47.0 + 14.0)
hw4 = (7.5 + 26.0) / (9.0 + 26.0)
hw5 = (33.0 + 6) / (34.0 + 6)
hw6 = (38 / 40)
hw7 = (30.75 + 8) / (34.0 + 11)
hw8 = (17 / 17)
hw9 = (11.0 + 8) / (11.0 + 10)
hw10 = 1
hw11 = (13 + 19) / (14 + 19)
hw12 = 1

# %%
hws = [hw0, hw1, hw2, hw3, hw4, hw5, hw6, hw7, hw8, hw9, hw10, hw11, hw12]
print(hws)
# Out:
# [1.0, 0.9705882352941176, 0.9142857142857143, 0.9639344262295082, 0.9571428571428572, 0.975, 0.95, 0.8611111111111112, 1.0, 0.9047619047619048, 1, 0.9696969696969697, 1]

# %%
hws.sort(reverse=True)
hws
# Out:
# [1.0,
#  1.0,
#  1,
#  1,
#  0.975,
#  0.9705882352941176,
#  0.9696969696969697,
#  0.9639344262295082,
#  0.9571428571428572,
#  0.95,
#  0.9142857142857143,
#  0.9047619047619048,
#  0.8611111111111112]

# %%
hw = (sum(hws[:9]) / 9) * 35
print(hw)
# Out:
# 34.363631899191205

# %%
labs = 10.0

# %%
disc = 20.0

# %%
mt = (88.8336 / 108.0) * 15.0

# %%
hw + disc + labs + mt
# Out:
# 76.7016318991912

# %%
85.42 / 126
# Out:
# 0.677936507936508

# %%
final = (85.42 / 126) * 20.0

# %%
grade = hw + disc + labs + mt + final

# %%
grade
# Out:
# 90.26036205792136

# %%
final_boundary = ((89.0000000000000001 - (hw + disc + labs + mt)) / 20) * 100
final_boundary
# Out:
# 61.491840504044006
